# %% [markdown]
# # Pandas
#
# We'll breeze through the basics here, and get onto some assignments in a bit. I want to provide the *barest* of intuition so things stick down the road.
#
# ## Why pandas?
#
# NumPy is great. But it lacks a few things that are conducive to doing statisitcal analysis. By building on top of NumPy, pandas provides
#
# - labeled arrays
# - heterogenous data types within a table
# - "better" missing data handling
# - convenient methods (`groupby`, `rolling`, `resample`)
# - more data types (Categorical, Datetime)
#
# ## Data Structures
#
# This is the typical starting point for any intro to pandas.
# We'll follow suit.
#
# ### The DataFrame
#
# Here we have the workhorse data structure for pandas.
# It's an in-memory table holding your data, and provides a few conviniences over lists of lists or NumPy arrays.

# %%
import numpy as np
import pandas as pd

# %%
# Many ways to construct a DataFrame
# We pass a dict of {column name: column values}
np.random.seed(42)
df = pd.DataFrame({'A': [1, 2, 3], 
                   'B': [True, True, False],
                   'C': np.random.randn(3)},
                  index=['a', 'b', 'c'])  # also this weird index thing
df
# Out:
#    A      B         C
# a  1   True  0.496714
# b  2   True -0.138264
# c  3  False  0.647689

# %% [markdown]
# Notice that we can store a column of intergers, a column of booleans, and a column of floats in the same `DataFrame`.

# %% [markdown]
# ### Indexing
#
# Our first improvement over numpy arrays is labeled indexing. We can select subsets by column, row, or both. Column selection uses the regular python `__getitem__` machinery. Pass in a single column label `'A'` or a list of labels `['A', 'C']` to select subsets of the original `DataFrame`.

# %%
# Single column, reduces to a Series
df['A']
# Out:
# a    1
# b    2
# c    3
# Name: A, dtype: int64

# %%
cols = ['A', 'C']
df[cols]
# Out:
#    A         C
# a  1  0.496714
# b  2 -0.138264
# c  3  0.647689

# %% [markdown]
# For row-wise selection, use the special `.loc` accessor.

# %%
df.loc[['a', 'b']]
# Out:
#    A     B         C
# a  1  True  0.496714
# b  2  True -0.138264

# %% [markdown]
# You can use ranges to select rows or columns.

# %%
df.loc['a':'b']
# Out:
#    A     B         C
# a  1  True  0.496714
# b  2  True -0.138264

# %% [markdown]
# Notice that the slice is *inclusive* on both sides,  unlike your typical slicing of a list. Sometimes, you'd rather slice by *position* instead of label. `.iloc` has you covered:

# %%
df.iloc[[0, 1]]
# Out:
#    A     B         C
# a  1  True  0.496714
# b  2  True -0.138264

# %%
df.iloc[:2]
# Out:
#    A     B         C
# a  1  True  0.496714
# b  2  True -0.138264

# %% [markdown]
# This follows the usual python slicing rules: closed on the left, open on the right.
#
# As I mentioned, you can slice both rows and columns. Use `.loc` for label or `.iloc` for position indexing.

# %%
df.loc['a', 'B']
# Out:
# True

# %% [markdown]
# Pandas, like NumPy, will reduce dimensions when possible. Select a single column and you get back `Series` (see below). Select a single row and single column, you get a scalar.
#
# You can get pretty fancy:

# %%
df.loc['a':'b', ['A', 'C']]
# Out:
#    A         C
# a  1  0.496714
# b  2 -0.138264

# %% [markdown]
# #### Summary
#
# - Use `[]` for selecting columns
# - Use `.loc[row_lables, column_labels]` for label-based indexing
# - Use `.iloc[row_positions, column_positions]` for positional index
#
# I've left out boolean and hierarchical indexing, which we'll see later.

# %% [markdown]
# ## Series
#
# You've already seen some `Series` up above. It's the 1-dimensional analog of the DataFrame. Each column in a `DataFrame` is in some sense a `Series`. You can select a `Series` from a DataFrame in a few ways:

# %%
# __getitem__ like before
df['A']
# Out:
# a    1
# b    2
# c    3
# Name: A, dtype: int64

# %%
# .loc, like before
df.loc[:, 'A']
# Out:
# a    1
# b    2
# c    3
# Name: A, dtype: int64

# %%
# using `.` attribute lookup
df.A
# Out:
# a    1
# b    2
# c    3
# Name: A, dtype: int64

# %%
df['mean'] = ['a', 'b', 'c']

# %%
df['mean']

# %%
df.mean

# %% [markdown]
# You'll have to be careful with the last one. It won't work if you're column name isn't a valid python identifier (say it has a space) or if it conflicts with one of the (many) methods on `DataFrame`. The `.` accessor is extremely convient for interactive use though.
#
# You should never *assign* a column with `.` e.g. don't do
#
# ```python
# # bad
# df.A = [1, 2, 3]
# ```
#
# It's unclear whether your attaching the list `[1, 2, 3]` as an attribute of `df`, or whether you want it as a column. It's better to just say
#
# ```python
# df['A'] = [1, 2, 3]
# # or
# df.loc[:, 'A'] = [1, 2, 3]
# ```
#
# `Series` share many of the same methods as `DataFrame`s.

# %% [markdown]
# ## Index
#
# `Index`es are something of a peculiarity to pandas.
# First off, they are not the kind of indexes you'll find in SQL, which are used to help the engine speed up certain queries.
# In pandas, `Index`es are about lables. This helps with selection (like we did above) and automatic alignment when performing operations between two `DataFrame`s or `Series`.
#
# R does have row labels, but they're nowhere near as powerful (or complicated) as in pandas. You can access the index of a `DataFrame` or `Series` with the `.index` attribute.

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# ## Operations

# %%
np.random.seed(42)
df = pd.DataFrame(np.random.uniform(0, 10, size=(3, 3)))
df
# Out:
#           0         1         2
# 0  3.745401  9.507143  7.319939
# 1  5.986585  1.560186  1.559945
# 2  0.580836  8.661761  6.011150

# %%
df + 1
# Out:
#           0          1         2
# 0  4.745401  10.507143  8.319939
# 1  6.986585   2.560186  2.559945
# 2  1.580836   9.661761  7.011150

# %%
df ** 2
# Out:
#            0          1          2
# 0  14.028030  90.385769  53.581513
# 1  35.839198   2.434182   2.433429
# 2   0.337371  75.026112  36.133926

# %%
np.log(df)
# Out:
#           0         1         2
# 0  1.320529  2.252043  1.990602
# 1  1.789521  0.444805  0.444651
# 2 -0.543287  2.158918  1.793616

# %% [markdown]
# DataFrames and Series have a bunch of useful aggregation methods, `.mean`, `.max`, `.std`, etc.

# %%
df.mean()
# Out:
# 0    3.437607
# 1    6.576364
# 2    4.963678
# dtype: float64

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('beer_subset.csv.gz', parse_dates=['time'], compression='gzip')
review_cols = ['review_appearance', 'review_aroma', 'review_overall',
               'review_palate', 'review_taste']
df.head(100)
# Out:
#      abv  beer_id  brewer_id  \
# 0    7.0     2511        287
# 1    5.7    19736       9790
# 2    4.8    11098       3182
# 3    9.5    28577       3818
# 4    5.8      398        119
# 5    7.0      966        365
# 6    6.2    53128       1114
# 7    4.8     1669        256
# 8    6.7     6549        140
# 9    6.5    13824        743
# 10  11.8    43670        423
# 11   6.3    53129      14365
# 12   NaN     4765       1500
# 13   8.0      652         24
# 14   5.2    53130       1114
# 15   5.2     2266        378
# 16   8.0    36179       3818
# 17   7.6       99        142
# 18   6.2    51573         96
# 19   5.0      717        256
# 20   5.0      571        113
# 21   4.6      401        118
# 22   4.9     5044      18968
# 23   6.5    44727        596
# 24   8.5    42303        106
# 25   9.4    40340       9550
# 26   5.9    37477        140
# 27   5.6    20206       9790
# 28   4.6      401        118
# 29   5.5     7799       1628
# ..   ...      ...        ...
# 70   5.5    22357        141
# 71   7.9      387        124
# 72   8.5    40310       4261
# 73   8.5    36527          4
# 74   5.2      637        203
# 75   4.0    53136       6045
# 76   5.5     7799       1628
# 77   4.1     9166       6045
# 78   5.1      299         96
# 79   8.5     5426       2085
# 80   4.5     2970         91
# 81   8.5      695        222
# 82   6.9    47919      13307
# 83   7.0     1093        287
# 84   6.5     8047         47
# 85   5.0     1120        139
# 86   8.2    37774         72
# 87  10.3    47317         35
# 88   6.0    50299       1114
# 89   4.2      754        209
# 90   5.0     2477        718
# 91   5.4      221         71
# 92   9.0    39379      15237
# 93  12.0     6354        669
# 94  10.0    31323       5318
# 95  10.0    25756        898
# 96   6.8    48243        923
# 97   6.0       39         26
# 98   4.8    47797       2431
# 99   9.4    46858       2681
#
#                                            beer_name  \
# 0                                Bell's Cherry Stout
# 1                                 Duck-Rabbit Porter
# 2                       Fürstenberg Premium Pilsener
# 3                Unearthly (Imperial India Pale Ale)
# 4                                 Wolaver's Pale Ale
# 5                            Pike Street XXXXX Stout
# 6                       Smokin' Amber Kegs Gone Wild
# 7                                        Great White
# 8            Northern Hemisphere Harvest Wet Hop Ale
# 9                                        Oktoberfest
# 10                         Bourbon Barrel Quad (BBQ)
# 11                                   Seneca Pale Ale
# 12                             Brown Hound Brown Ale
# 13                                 Traquair Jacobite
# 14                          El Hefe Dunkle Gone Wild
# 15                          Bar Harbor Blueberry Ale
# 16                   Hoppe (Imperial Extra Pale Ale)
# 17                                  Spaten Optimator
# 18                            Odd Notion (Fall 2009)
# 19                                    Downtown Brown
# 20                      Samuel Smith's Oatmeal Stout
# 21                                       Dark Island
# 22                                       Kipona Fest
# 23                              Portsmouth 5 C's IPA
# 24      Schlitz High Gravity V.S.L Very Smooth Lager
# 25                                 Oak-Aged Ebenezer
# 26         Sierra Nevada Anniversary Ale (2007-2009)
# 27                             Duck-Rabbit Brown Ale
# 28                                       Dark Island
# 29                           Southampton Pumpkin Ale
# ..                                               ...
# 70                          Smuttynose Summer Weizen
# 71                              Salvator Doppel Bock
# 72                                   Noël Des Géants
# 73                              Allagash Hugh Malone
# 74                                  Old Speckled Hen
# 75                               English Session Ale
# 76                           Southampton Pumpkin Ale
# 77                                   Raspberry Wheat
# 78                                                #9
# 79               Dragonmead Final Absolution Trippel
# 80                           Taj Mahal Premium Lager
# 81                                             Duvel
# 82                            Warrior Single Hop IPA
# 83                                   Two Hearted Ale
# 84                                   Boon Oude Kriek
# 85                               Shipyard Export Ale
# 86                Schneider-Brooklyner Hopfen-Weisse
# 87                       Samuel Adams Imperial White
# 88                                         Frambozen
# 89                                  Guinness Draught
# 90                                        Wittekerke
# 91                            Fuller's London Porter
# 92                   Struise Mikkeller (Elliot Brew)
# 93                                       Malheur 12°
# 94                                            Hop 15
# 95  Heavy Seas - Below Decks (Barley Wine Style Ale)
# 96                                   Modus Hoperandi
# 97                               Alpha King Pale Ale
# 98                                    Germania Lager
# 99                         Ten FIDY (Whiskey Barrel)
#
#                           beer_style  review_appearance  review_aroma  \
# 0                     American Stout                4.5           4.0
# 1                    American Porter                4.5           4.0
# 2                    German Pilsener                4.0           3.0
# 3     American Double / Imperial IPA                4.0           4.0
# 4            American Pale Ale (APA)                4.0           3.0
# 5                     American Stout                4.0           4.0
# 6           American Amber / Red Ale                3.5           4.0
# 7                            Witbier                4.5           4.5
# 8                       American IPA                4.0           4.0
# 9                       Vienna Lager                3.0           2.5
# 10                  Quadrupel (Quad)                4.5           4.0
# 11           American Pale Ale (APA)                3.0           3.5
# 12                 English Brown Ale                4.0           4.0
# 13            Scotch Ale / Wee Heavy                4.5           4.5
# 14                      Dunkelweizen                3.5           3.5
# 15            Fruit / Vegetable Beer                3.0           3.0
# 16    American Double / Imperial IPA                4.0           3.0
# 17                        Doppelbock                3.0           4.0
# 18                  Belgian Dark Ale                4.0           3.5
# 19                 English Brown Ale                4.0           4.0
# 20                     Oatmeal Stout                4.0           4.0
# 21                      Scottish Ale                4.0           4.0
# 22              Märzen / Oktoberfest                4.0           3.5
# 23                      American IPA                4.5           5.0
# 24              American Malt Liquor                3.0           3.0
# 25  American Double / Imperial Stout                4.5           4.0
# 26                      American IPA                4.5           4.5
# 27                American Brown Ale                4.0           3.5
# 28                      Scottish Ale                4.0           4.0
# 29                       Pumpkin Ale                3.5           3.5
# ..                               ...                ...           ...
# 70           American Pale Wheat Ale                3.5           4.0
# 71                        Doppelbock                5.0           3.5
# 72              Herbed / Spiced Beer                3.5           4.0
# 73                       Belgian IPA                4.5           4.5
# 74                  English Pale Ale                3.5           2.5
# 75                    English Bitter                4.0           3.5
# 76                       Pumpkin Ale                3.0           2.5
# 77            Fruit / Vegetable Beer                3.0           3.5
# 78            Fruit / Vegetable Beer                4.0           4.0
# 79                            Tripel                3.5           4.0
# 80            American Adjunct Lager                3.0           2.5
# 81           Belgian Strong Pale Ale                4.0           4.5
# 82                      American IPA                4.0           4.0
# 83                      American IPA                4.0           3.5
# 84                    Lambic - Fruit                4.5           4.0
# 85               American Blonde Ale                3.5           2.5
# 86                        Weizenbock                4.0           3.5
# 87                           Witbier                4.0           3.5
# 88                 American Wild Ale                4.0           4.0
# 89                   Irish Dry Stout                4.5           3.0
# 90                           Witbier                3.5           3.5
# 91                    English Porter                3.5           4.0
# 92    American Double / Imperial IPA                4.0           4.0
# 93                  Quadrupel (Quad)                4.0           4.0
# 94    American Double / Imperial IPA                4.0           4.5
# 95                English Barleywine                3.0           3.5
# 96                      American IPA                4.0           4.0
# 97           American Pale Ale (APA)                4.0           4.5
# 98                   Euro Pale Lager                3.0           3.5
# 99  American Double / Imperial Stout                4.5           4.5
#
#     review_overall  review_palate     profile_name  review_taste  \
# 0              4.5            4.0         blaheath           4.5
# 1              4.5            4.0             GJ40           4.0
# 2              3.0            3.0         biegaman           3.5
# 3              4.0            4.0           nick76           4.0
# 4              4.0            3.5         champ103           3.0
# 5              3.5            4.0        sprucetip           4.5
# 6              4.5            4.0           Deuane           4.5
# 7              4.5            4.5           n0rc41           4.5
# 8              4.0            4.0          david18           4.0
# 9              2.5            2.5         Seanibus           2.5
# 10             4.5            4.5         blaheath           4.5
# 11             4.5            4.0       Daniellobo           4.0
# 12             4.0            4.0        CheckMate           4.0
# 13             4.5            4.5            drtth           4.5
# 14             4.0            3.5           Deuane           4.0
# 15             2.0            3.0         smanders           3.0
# 16             4.0            3.5           nick76           3.0
# 17             4.0            3.0         drcarver           3.5
# 18             3.5            4.5           DannyS           4.0
# 19             4.0            4.0           n0rc41           4.0
# 20             4.0            4.5             SamN           3.5
# 21             3.5            4.0       abuliarose           4.0
# 22             4.0            4.0         drcarver           4.0
# 23             5.0            4.5             ALeF           5.0
# 24             2.0            2.5  twiggamortis420           2.0
# 25             4.0            4.5     msubulldog25           4.0
# 26             4.5            4.5           n0rc41           4.5
# 27             4.0            3.5             GJ40           4.0
# 28             4.5            4.0        sisuspeed           4.0
# 29             4.0            4.0     indiapaleale           3.5
# ..             ...            ...              ...           ...
# 70             4.0            4.0         edchicma           4.0
# 71             5.0            4.5        Marcrates           4.5
# 72             4.0            3.5           jdhilt           4.0
# 73             4.0            4.0      ShogoKawada           4.5
# 74             3.5            3.5          mdwalsh           3.5
# 75             4.0            3.5       beerthulhu           3.5
# 76             3.0            4.0       Mistofminn           3.0
# 77             3.5            3.5       beerthulhu           4.0
# 78             3.5            3.0      wheatyweiss           3.0
# 79             4.0            3.5         brentk56           4.0
# 80             2.5            2.5        wertperch           2.5
# 81             5.0            4.0        MrDanno96           4.5
# 82             4.0            4.0     CHILLINDYLAN           4.0
# 83             3.0            3.5           tone77           3.0
# 84             4.5            4.0    philipquarles           4.5
# 85             2.5            3.5          TexIndy           2.5
# 86             4.5            4.5         champ103           4.5
# 87             3.0            2.5           bnes09           3.5
# 88             4.0            4.0        largadeer           4.0
# 89             3.5            4.0          MrStark           3.0
# 90             3.5            4.0           tone77           3.5
# 91             4.0            4.0        ludachris           4.0
# 92             4.0            4.0     CHILLINDYLAN           4.0
# 93             3.5            4.0          david18           3.5
# 94             4.0            4.0           JayQue           4.5
# 95             4.0            3.5         kzoobrew           4.0
# 96             4.0            4.5         biggred1           4.5
# 97             4.5            4.0     CHILLINDYLAN           4.5
# 98             3.5            3.0           tone77           3.5
# 99             4.5            5.0       Bitterbill           5.0
#
#                                                  text                time
# 0    Batch 8144\tPitch black in color with a 1/2 f... 2009-10-05 21:31:48
# 1    Sampled from a 12oz bottle in a standard pint... 2009-10-05 21:32:09
# 2    Haystack yellow with an energetic group of bu... 2009-10-05 21:32:13
# 3    The aroma has pine, wood, citrus, caramel, an... 2009-10-05 21:32:37
# 4    A: Pours a slightly hazy golden/orange color.... 2009-10-05 21:33:14
# 5    From notes. Pours black, thin mocha head fade... 2009-10-05 21:33:48
# 6    An American amber with the addition of smoked... 2009-10-05 21:34:24
# 7    Ok, for starters great white I believe will b... 2009-10-05 21:34:29
# 8    I like all of Sierra Nevada's beers but felt ... 2009-10-05 21:34:31
# 9    This actually winds up coming out like a ligh... 2009-10-05 21:35:09
# 10   Burnt amber in color with a 1/4" head. Aroma ... 2009-10-05 21:36:03
# 11   A very pleasing PA leaning strongly on the IP... 2009-10-05 21:37:48
# 12   1/2 gallon growler obtained at Whole Foods in... 2009-10-05 21:38:21
# 13   Lightly chilled and poured into a Duvel glass... 2009-10-05 21:40:18
# 14   A-Very deep, dark brown with a thin tan head ... 2009-10-05 21:42:35
# 15   Not usually a "fruity beer" kinda guy but my ... 2009-10-05 21:43:23
# 16   The aroma is papery with citrus, yeast, and s... 2009-10-05 21:43:23
# 17   I have had this beer numerous times in the pa... 2009-10-05 21:43:36
# 18   Poured from a 12 oz bottle into a pint glass.... 2009-10-05 21:44:19
# 19   Good all around beer. This is my girlfriends ... 2009-10-05 21:44:25
# 20   Purchased a bomber from Supermarket Liquors i... 2009-10-05 21:45:53
# 21   Poured into a snifter, revealing black opaque... 2009-10-05 21:47:36
# 22   A - a medium brown body with an off white hea... 2009-10-05 21:47:56
# 23   As a devoted drinker of American and English ... 2009-10-05 21:48:46
# 24   24 oz. of the golden bull, oh yeah. Pours a l... 2009-10-05 21:49:02
# 25   Caged/corked 750ml bottle split on a cool Sun... 2009-10-05 21:49:22
# 26   Poured a great dark color with great smell! t... 2009-10-05 21:51:33
# 27   Sampled from a 12oz bottle in a standard pint... 2009-10-05 21:51:33
# 28   The color of this beer fits the name well. Op... 2009-10-05 21:53:38
# 29   Pour - Southampton Pumpkin pours a very clean... 2009-10-05 22:00:37
# ..                                                ...                 ...
# 70   Pours a crystal lemon with a quickly dissipat... 2009-10-05 22:50:23
# 71   A - This is a beautiful looking beer. A very ... 2009-10-05 22:51:30
# 72   Pours a five finger, pale tan head that fades... 2009-10-05 22:52:49
# 73   A two-tier review. I made my notes while enjo... 2009-10-05 22:54:17
# 74   A: Pours a weak head. Even with an aggressive... 2009-10-05 22:55:10
# 75   4.0% abv. \t\tA: Poured into a pint with a ro... 2009-10-05 22:55:10
# 76   Thanks to JoeyBeerBelly for this extra, Thank... 2009-10-05 22:55:15
# 77   A: Poured a crystal golen-orange with a thin,... 2009-10-05 22:57:38
# 78   Poured from a bomber into a SA perfect. Label... 2009-10-05 23:00:35
# 79   Appearance: Pours a very cloudy chestnut colo... 2009-10-05 23:02:42
# 80   I had one of these at a local curry house. Po... 2009-10-05 23:06:44
# 81   A: Pours an opaque, light golden color with a... 2009-10-05 23:06:59
# 82   Hazed golden orange with a deep amber core. T... 2009-10-05 23:07:37
# 83   Poured from a brown 12oz. bottle. Has a cloud... 2009-10-05 23:09:17
# 84   375ml bottle. Pours a deep, fairly clear garn... 2009-10-05 23:10:14
# 85   Poured from a 12oz bottle into a pint glass. ... 2009-10-05 23:11:13
# 86   A: Pours a hazy orange/amber color. A large w... 2009-10-05 23:12:20
# 87   I'll give Sam Adams a hand for brewering some... 2009-10-05 23:13:25
# 88   750ml autographed bottle kindly shared by alf... 2009-10-05 23:13:32
# 89   Poured from a 14.9 oz nitro-can into a nonic ... 2009-10-05 23:14:11
# 90   Poured from a brown 11.2oz. bottle. Has a clo... 2009-10-05 23:16:24
# 91   Pours a coca-cola brown out of the can but en... 2009-10-05 23:17:09
# 92   Slightly hazy golden yellow with deep amber c... 2009-10-05 23:17:25
# 93   Dark brown appearance with a great light tan ... 2009-10-05 23:22:06
# 94   Good DIPA! Pours a hazy yellowish amber with ... 2009-10-05 23:22:19
# 95   2008 batch\t\tRich cooper to amber color capp... 2009-10-05 23:23:54
# 96   Copper orange with a solid finger of cream co... 2009-10-05 23:25:56
# 97   Clear orange copper. Thick chunky tannish hea... 2009-10-05 23:26:03
# 98   Poured from a green 11.2oz. bottle. Has a lig... 2009-10-05 23:26:20
# 99   Another tap filled bottle from my buddy NutBr... 2009-10-05 23:27:47
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Boolean indexing
#
# Like a where clause in SQL. The indexer (or boolean mask) should be 1-dimensional and the same length as the thing being indexed.

# %%
df.abv < 5
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# Name: abv, Length: 999, dtype: bool

# %%
df[df.abv < 5]
# Out:
#       abv  beer_id  brewer_id                                beer_name  \
# 2    4.80    11098       3182             Fürstenberg Premium Pilsener
# 7    4.80     1669        256                              Great White
# 21   4.60      401        118                              Dark Island
# 22   4.90     5044      18968                              Kipona Fest
# 28   4.60      401        118                              Dark Island
# 30   4.90      909        306                      Killian's Irish Red
# 40   4.10    51464         29                   Bud Light Golden Wheat
# 75   4.00    53136       6045                      English Session Ale
# 77   4.10     9166       6045                          Raspberry Wheat
# 80   4.50     2970         91                  Taj Mahal Premium Lager
# 89   4.20      754        209                         Guinness Draught
# 98   4.80    47797       2431                           Germania Lager
# 112  4.80      935        360                 Warsteiner Premium Verum
# 120  4.40     1351      23980              Yuengling Traditional Lager
# 121  4.40    28536         96                               Circus Boy
# 123  4.20    36811         29  Michelob Ultra Tuscan Orange Grapefruit
# 124  4.00    33405       1416                               Punk'n Ale
# 144  4.80      266         91                 Kingfisher Premium Lager
# 187  4.20    28268        590                                    Yokel
# 189  4.70    53108        853                   Black Oak Oaktoberfest
# 203  4.50      848         57                                   Tecate
# 209  4.90      104         35                Samuel Adams Boston Lager
# 215  4.40     2389        188                             Deuchars IPA
# 222  4.80    41213      16814                    Headbangerz Brown Ale
# 234  4.00    53147        435                        Minhas Creek Lime
# 235  4.60    53148      19726                      MacLean's Brown Ale
# 271  4.00    51602      14984                             Gone Fishin'
# 277  4.10    35735        105                             Miller Chill
# 285  4.60     5328        579                   Longboard Island Lager
# 288  4.70     6135        703                           Erdinger Champ
# ..    ...      ...        ...                                      ...
# 687  3.10    43889      16866               Hottenroth Berliner Weisse
# 721  4.50    53158        765                  Trafalgar Malted Corpse
# 723  4.20     7712        187                    Lindemans Faro Lambic
# 729  3.90    38723      16304                          Town Hall Lager
# 747  4.70     4367        751                         Summer Honey Ale
# 754  4.30    25694        912                         Presidente Light
# 756  4.68    38927      10990                            Indian Summer
# 773  3.10    43889      16866               Hottenroth Berliner Weisse
# 780  4.50    25044        583                          Schlafly Kölsch
# 783  4.39    22343      10990                           Southern Pecan
# 784  4.70    34804      16098                          Landshark Lager
# 786  4.60      867      10161                            Birra Moretti
# 792  4.70     1673         91                 Flying Horse Royal Lager
# 810  4.60      178         60                         Strike Out Stout
# 817  4.70      689        221                Red Stripe Jamaican Lager
# 828  4.20    41821         29                           Bud Light Lime
# 849  4.70    34804      16098                          Landshark Lager
# 850  4.70     3824       1417            Monty Python's Holy Grail Ale
# 863  3.50    53180      11212                           You're Welcome
# 864  4.80     1774        648                   Köstritzer Schwarzbier
# 874  4.90    45659        710              Leinenkugel's Classic Amber
# 881  4.00    36672      13014                            Bitter Brewer
# 882  4.60      900         94                               Pollenator
# 884  4.90    32575        143                     Bohemian Black Lager
# 896  4.80     6711       2854                       Flensburger Dunkel
# 901  4.20    53124      16304                             Vienna Lager
# 905  4.70    53108        853                   Black Oak Oaktoberfest
# 931  4.80      771        282               Entire Butt English Porter
# 934  4.00    23261      11212                     Rodeo Extra Pale Ale
# 936  4.50    53158        765                  Trafalgar Malted Corpse
#
#                        beer_style  review_appearance  review_aroma  \
# 2                 German Pilsener                4.0           3.0
# 7                         Witbier                4.5           4.5
# 21                   Scottish Ale                4.0           4.0
# 22           Märzen / Oktoberfest                4.0           3.5
# 28                   Scottish Ale                4.0           4.0
# 30     American Amber / Red Lager                4.0           3.5
# 40           Herbed / Spiced Beer                3.0           3.0
# 75                 English Bitter                4.0           3.5
# 77         Fruit / Vegetable Beer                3.0           3.5
# 80         American Adjunct Lager                3.0           2.5
# 89                Irish Dry Stout                4.5           3.0
# 98                Euro Pale Lager                3.0           3.5
# 112               German Pilsener                3.5           3.0
# 120    American Amber / Red Lager                3.5           3.0
# 121       American Pale Wheat Ale                4.0           3.5
# 123                   Light Lager                2.5           2.5
# 124                   Pumpkin Ale                3.0           3.5
# 144           American Pale Lager                2.5           3.0
# 187    Keller Bier / Zwickel Bier                3.0           3.5
# 189          Märzen / Oktoberfest                4.0           3.5
# 203        American Adjunct Lager                3.5           2.5
# 209                  Vienna Lager                3.5           3.0
# 215  English India Pale Ale (IPA)                3.0           3.0
# 222             English Brown Ale                4.0           3.0
# 234        American Adjunct Lager                2.5           2.0
# 235             English Brown Ale                3.5           3.5
# 271         English Dark Mild Ale                4.0           4.0
# 277                   Light Lager                1.5           2.0
# 285           American Pale Lager                4.0           3.5
# 288                    Hefeweizen                3.0           3.5
# ..                            ...                ...           ...
# 687            Berliner Weissbier                3.0           4.0
# 721                 Irish Red Ale                3.0           3.0
# 723                          Faro                4.0           3.5
# 729    American Amber / Red Lager                3.0           4.0
# 747       American Pale Ale (APA)                3.0           3.0
# 754                   Light Lager                3.5           3.0
# 756       American Pale Wheat Ale                3.5           3.5
# 773            Berliner Weissbier                3.5           4.0
# 780                        Kölsch                3.5           4.0
# 783             English Brown Ale                3.5           3.5
# 784        American Adjunct Lager                3.0           2.5
# 786               Euro Pale Lager                2.0           2.0
# 792        American Adjunct Lager                3.0           2.5
# 810                 English Stout                4.5           4.0
# 817        American Adjunct Lager                4.0           3.5
# 828                   Light Lager                3.0           2.5
# 849        American Adjunct Lager                3.0           3.0
# 850              English Pale Ale                3.5           3.0
# 863         English Dark Mild Ale                4.0           3.0
# 864                   Schwarzbier                4.5           4.0
# 874    American Amber / Red Lager                3.5           4.0
# 881                English Bitter                4.5           4.0
# 882       American Pale Ale (APA)                3.5           3.0
# 884                   Schwarzbier                3.0           3.0
# 896           Munich Dunkel Lager                3.5           3.5
# 901                  Vienna Lager                3.5           4.0
# 905          Märzen / Oktoberfest                5.0           4.0
# 931                English Porter                3.0           3.5
# 934       American Pale Ale (APA)                4.0           3.5
# 936                 Irish Red Ale                3.5           2.5
#
#      review_overall  review_palate     profile_name  review_taste  \
# 2               3.0            3.0         biegaman           3.5
# 7               4.5            4.5           n0rc41           4.5
# 21              3.5            4.0       abuliarose           4.0
# 22              4.0            4.0         drcarver           4.0
# 28              4.5            4.0        sisuspeed           4.0
# 30              3.5            3.0           tone77           3.0
# 40              3.5            3.5           armock           3.5
# 75              4.0            3.5       beerthulhu           3.5
# 77              3.5            3.5       beerthulhu           4.0
# 80              2.5            2.5        wertperch           2.5
# 89              3.5            4.0          MrStark           3.0
# 98              3.5            3.0           tone77           3.5
# 112             4.0            4.0      biboergosum           4.0
# 120             4.5            4.5          MrStark           4.5
# 121             3.5            3.5           tone77           3.5
# 123             2.5            3.0     mooseisloose           2.5
# 124             3.5            3.0           bbeane           3.5
# 144             3.0            3.0        wertperch           3.5
# 187             4.5            3.5      AdmiralDiaz           4.0
# 189             4.0            4.5   northyorksammy           4.0
# 203             3.0            3.0         Florida9           2.0
# 209             4.0            4.5       EsoxLucius           4.0
# 215             2.5            3.0    MeisterBurger           3.0
# 222             3.5            3.5         corby112           3.5
# 234             2.0            2.0       EsoxLucius           1.5
# 235             3.0            3.0   northyorksammy           3.0
# 271             4.0            4.0          Wasatch           4.0
# 277             2.0            2.0   TheManiacalOne           2.5
# 285             3.5            2.5       crossovert           3.5
# 288             3.5            3.0   TheManiacalOne           3.0
# ..              ...            ...              ...           ...
# 687             4.5            4.0        younger35           4.5
# 721             2.5            2.5        mrmanning           3.0
# 723             3.5            3.5         DerBayer           4.0
# 729             4.0            4.0        GodOfBeer           4.0
# 747             3.5            3.0        brownbeer           3.0
# 754             2.0            2.0     donkeyrunner           2.0
# 756             3.5            3.5            mjl21           3.5
# 773             5.0            3.5           ATPete           4.0
# 780             4.5            4.0          Dave412           4.0
# 783             4.0            4.0            mjl21           4.0
# 784             3.5            3.5       Sheeeeeeep           3.5
# 786             2.5            2.5  crowncapcollect           2.0
# 792             3.5            3.0       Sheeeeeeep           2.5
# 810             4.0            4.0       puboflyons           4.0
# 817             3.5            3.0         BeerCon5           3.5
# 828             4.0            3.5          FatSean           3.0
# 849             4.0            3.5         Bajasith           3.5
# 850             3.0            3.0           armock           3.0
# 863             3.0            3.5       RedDiamond           3.0
# 864             4.5            4.0         Bajasith           4.5
# 874             4.5            3.0      woosterbill           3.5
# 881             4.5            3.5         jlindros           4.5
# 882             3.5            3.5       NJpadreFan           3.5
# 884             2.5            3.0       jpschouest           2.5
# 896             4.5            4.0        drpimento           3.5
# 901             3.5            4.0            Derek           3.5
# 905             4.5            4.5            Derek           4.0
# 931             3.5            3.5       scoobybrew           3.5
# 934             3.0            3.0       RedDiamond           3.5
# 936             2.0            2.0            Viggo           2.0
#
#                                                   text                time
# 2     Haystack yellow with an energetic group of bu... 2009-10-05 21:32:13
# 7     Ok, for starters great white I believe will b... 2009-10-05 21:34:29
# 21    Poured into a snifter, revealing black opaque... 2009-10-05 21:47:36
# 22    A - a medium brown body with an off white hea... 2009-10-05 21:47:56
# 28    The color of this beer fits the name well. Op... 2009-10-05 21:53:38
# 30    Poured from a brown 12oz. bottle. Has an ambe... 2009-10-05 22:01:09
# 40    A - Poured a hazy orange color with a white h... 2009-10-05 22:11:53
# 75    4.0% abv. \t\tA: Poured into a pint with a ro... 2009-10-05 22:55:10
# 77    A: Poured a crystal golen-orange with a thin,... 2009-10-05 22:57:38
# 80    I had one of these at a local curry house. Po... 2009-10-05 23:06:44
# 89    Poured from a 14.9 oz nitro-can into a nonic ... 2009-10-05 23:14:11
# 98    Poured from a green 11.2oz. bottle. Has a lig... 2009-10-05 23:26:20
# 112   This beer pours a clear medium golden hue, wi... 2009-10-05 23:41:02
# 120   Poured from a 12 oz bottle into a pilsener gl... 2009-10-05 23:44:08
# 121   Poured from a brown 12oz. bottle. Has a cloud... 2009-10-05 23:44:36
# 123   This one was in the frig and I've never revie... 2009-10-05 23:47:15
# 124   A- Poured into a 16oz tumbler... after an agr... 2009-10-05 23:47:25
# 144   I drank one of these after the Taj Mahal Prem... 2009-10-06 00:12:48
# 187   Pours bright gold with a weak white head that... 2009-10-06 00:55:56
# 189   Very decent cask format beer, enjoyed at C'es... 2009-10-06 00:58:29
# 203   Lost my detailed notes on this one. Suffice t... 2009-10-06 01:07:43
# 209   Poured from a 355ml bottle.\t\tI normally can... 2009-10-06 01:14:15
# 215   A: Light golden amber with a thin white head.... 2009-10-06 01:16:45
# 222   Pours a murky dark chestnut brown color with ... 2009-10-06 01:20:00
# 234   another, yes, another lime beer on the market... 2009-10-06 01:25:30
# 235   Cask at C'est What. Cloudy medium brown with ... 2009-10-06 01:27:11
# 271   Thanks goes out to JohnGalt1 for this brew.\t... 2009-10-06 02:11:09
# 277   Poured from a 12oz bottle into a US tumbler p... 2009-10-06 02:14:01
# 285   Really needed something refreshing tonight an... 2009-10-06 02:17:18
# 288   Poured from an 11.2oz bottle into a US tumble... 2009-10-06 02:18:13
# ..                                                 ...                 ...
# 687   Received this brew recently from the every ge... 2009-10-06 20:36:10
# 721   Bottle from the LCBO- A very still, cola brow... 2009-10-06 21:36:46
# 723   Well what can I say it s a sweet and sour bee... 2009-10-06 21:40:20
# 729   Pours a light gold with a thin white head, so... 2009-10-06 21:47:13
# 747   A- gold with a white head.\t\tS- Grainy aroma... 2009-10-06 22:06:05
# 754   I had a party and some one left this landmine... 2009-10-06 22:11:12
# 756   12 ounce bottle poured into a pint glass. Dat... 2009-10-06 22:11:38
# 773   capped 750ml\t\tPours a super pale yellow wit... 2009-10-06 22:23:24
# 780   A. Pale golden color, finger+ length head.\t\... 2009-10-06 22:28:01
# 783   12 ounce bottle poured into a pint glass. No ... 2009-10-06 22:29:44
# 784   Enjoyable beer with a nice bite to it. Not ex... 2009-10-06 22:30:10
# 786   330ml bottle.\t\tLooks like piss, tastes like... 2009-10-06 22:31:53
# 792   Almost unexceptional in comparison to it's pe... 2009-10-06 22:36:39
# 810   From the 12 fl. oz. bottle with no obvious lo... 2009-10-06 22:55:41
# 817   Pours a clear strawlike yellow color with two... 2009-10-06 23:03:38
# 828   I broke down and bought a 22oz of this beer, ... 2009-10-06 23:20:09
# 849   Great beer to have if you are out-side cookin... 2009-10-06 23:48:29
# 850   A - Poured a light copper color with a white ... 2009-10-06 23:48:57
# 863   This courteous small beer is brewed from the ... 2009-10-07 00:03:30
# 864   Very nice pour with exceptional two finger he... 2009-10-07 00:03:58
# 874   12 oz bottle into a Duvel tulip.\t\tA: Pours ... 2009-10-07 00:17:30
# 881   Got this nice lookin tall boy in a big Surly-... 2009-10-07 00:22:15
# 882   Long Trail- Pollenator\t\tA- Light yellow wit... 2009-10-07 00:24:59
# 884   Poured into a clear 20 oz pint glass it had a... 2009-10-07 00:28:12
# 896   Nice beer. Got this bottle a couple of weeks ... 2009-10-07 00:39:31
# 901   A: Deep bronze, off-white head, thin ring of ... 2009-10-07 00:42:17
# 905   A: Copper with an off-white head, great reten... 2009-10-07 00:45:55
# 931   This was poured into a pint glass.\t\tA - dee... 2009-10-07 01:00:04
# 934   Iron Horse's website lists Rodeo at 4% ABV, w... 2009-10-07 01:01:35
# 936   650 ml bottle from the LCBO. These new labels... 2009-10-07 01:01:55
#
# [116 rows x 13 columns]

# %% [markdown]
# Notice that we just used `[]` there. We can pass the boolean indexer in to `.loc` as well.

# %%
df.loc[df.abv < 5, ['beer_style', 'review_overall']].head()

# %% [markdown]
# Again, you can get complicated

# %%
df[((df.abv < 5) & (df.time > pd.Timestamp('2009-06'))) | (df.review_overall >= 4.5)]
# Out:
#        abv  beer_id  brewer_id                                  beer_name  \
# 0     7.00     2511        287                        Bell's Cherry Stout
# 1     5.70    19736       9790                         Duck-Rabbit Porter
# 2     4.80    11098       3182               Fürstenberg Premium Pilsener
# 6     6.20    53128       1114               Smokin' Amber Kegs Gone Wild
# 7     4.80     1669        256                                Great White
# 10   11.80    43670        423                  Bourbon Barrel Quad (BBQ)
# 11    6.30    53129      14365                            Seneca Pale Ale
# 13    8.00      652         24                          Traquair Jacobite
# 21    4.60      401        118                                Dark Island
# 22    4.90     5044      18968                                Kipona Fest
# 23    6.50    44727        596                       Portsmouth 5 C's IPA
# 26    5.90    37477        140  Sierra Nevada Anniversary Ale (2007-2009)
# 28    4.60      401        118                                Dark Island
# 30    4.90      909        306                        Killian's Irish Red
# 33    5.40      159        158                            Denver Pale Ale
# 40    4.10    51464         29                     Bud Light Golden Wheat
# 44    8.50      695        222                                      Duvel
# 52     NaN    37149       5408                                       Gose
# 55    5.50    51512      20681                                 Peeper Ale
# 56    5.80    38365         35                     Samuel Adams Irish Red
# 58     NaN    53133       5408                                Oktoberfest
# 60    6.50    13896         73                    Great Lakes Oktoberfest
# 67    6.90       88        147                 Stone IPA (India Pale Ale)
# 69    5.40    48928       6045                         American Brown Ale
# 71    7.90      387        124                       Salvator Doppel Bock
# 75    4.00    53136       6045                        English Session Ale
# 77    4.10     9166       6045                            Raspberry Wheat
# 80    4.50     2970         91                    Taj Mahal Premium Lager
# 81    8.50      695        222                                      Duvel
# 84    6.50     8047         47                            Boon Oude Kriek
# ..     ...      ...        ...                                        ...
# 909   5.80    20512       1853                                Oktoberfest
# 910   8.00    45017       7730        Doppelt IPA - Double India Pale Ale
# 914   8.50    52828        147       Kona Coffee Macadamia Coconut Porter
# 915  10.00      945        173                                       Adam
# 916   7.90     5527       1590                             Industrial IPA
# 918   5.20    19685       9629                 Short's Bellaire Brown Ale
# 919   5.40      221         71                     Fuller's London Porter
# 921   9.00    30288        392                          Double Simcoe IPA
# 930  11.00    37811       5221                                   Tuverbol
# 931   4.80      771        282                 Entire Butt English Porter
# 933   7.50    38180       2210                  Union Jack India Pale Ale
# 934   4.00    23261      11212                       Rodeo Extra Pale Ale
# 936   4.50    53158        765                    Trafalgar Malted Corpse
# 940   6.70     6549        140    Northern Hemisphere Harvest Wet Hop Ale
# 942   8.00    25435         26                                     Moloko
# 948   6.40    36341       1683                           State Pen Porter
# 950   7.40     4629         26                              Rabbid Rabbit
# 959   8.74    52077        220                A Little Sumpin' Extra! Ale
# 961   8.50    52828        147       Kona Coffee Macadamia Coconut Porter
# 968   5.30     1374        467                      Summit Extra Pale Ale
# 971  12.00    17538       1199                      Founders Devil Dancer
# 972   9.50     1558         26                            Dreadnaught IPA
# 975   5.40      186        141                 Smuttynose Shoals Pale Ale
# 976   8.00     5057        738                             Fantôme Saison
# 980  10.60    47140        119         Otter Creek Russian Imperial Stout
# 987   7.20    39296      14400                                      Oatis
# 989   7.00      782        113              Samuel Smith's Imperial Stout
# 992   5.70    46767          8                           Drifter Pale Ale
# 993  10.00    36728      18149                            10 Commandments
# 995   6.50    49728       2874                       St. Feuillien Saison
#
#                          beer_style  review_appearance  review_aroma  \
# 0                    American Stout                4.5           4.0
# 1                   American Porter                4.5           4.0
# 2                   German Pilsener                4.0           3.0
# 6          American Amber / Red Ale                3.5           4.0
# 7                           Witbier                4.5           4.5
# 10                 Quadrupel (Quad)                4.5           4.0
# 11          American Pale Ale (APA)                3.0           3.5
# 13           Scotch Ale / Wee Heavy                4.5           4.5
# 21                     Scottish Ale                4.0           4.0
# 22             Märzen / Oktoberfest                4.0           3.5
# 23                     American IPA                4.5           5.0
# 26                     American IPA                4.5           4.5
# 28                     Scottish Ale                4.0           4.0
# 30       American Amber / Red Lager                4.0           3.5
# 33                 English Pale Ale                5.0           4.0
# 40             Herbed / Spiced Beer                3.0           3.0
# 44          Belgian Strong Pale Ale                4.0           4.5
# 52                             Gose                4.0           4.5
# 55          American Pale Ale (APA)                4.5           5.0
# 56                    Irish Red Ale                4.5           4.0
# 58             Märzen / Oktoberfest                4.0           4.0
# 60             Märzen / Oktoberfest                4.5           3.5
# 67                     American IPA                4.0           4.5
# 69               American Brown Ale                4.0           4.0
# 71                       Doppelbock                5.0           3.5
# 75                   English Bitter                4.0           3.5
# 77           Fruit / Vegetable Beer                3.0           3.5
# 80           American Adjunct Lager                3.0           2.5
# 81          Belgian Strong Pale Ale                4.0           4.5
# 84                   Lambic - Fruit                4.5           4.0
# ..                              ...                ...           ...
# 909            Märzen / Oktoberfest                4.0           4.0
# 910  American Double / Imperial IPA                4.5           4.0
# 914                 American Porter                4.0           4.0
# 915                         Old Ale                4.5           4.5
# 916  American Double / Imperial IPA                4.5           4.0
# 918              American Brown Ale                3.5           4.5
# 919                  English Porter                4.0           4.0
# 921  American Double / Imperial IPA                4.0           4.5
# 930              Lambic - Unblended                5.0           4.5
# 931                  English Porter                3.0           3.5
# 933                    American IPA                4.0           4.0
# 934         American Pale Ale (APA)                4.0           3.5
# 936                   Irish Red Ale                3.5           2.5
# 940                    American IPA                4.5           4.5
# 942              Milk / Sweet Stout                4.0           4.0
# 948                 American Porter                4.0           3.5
# 950          Saison / Farmhouse Ale                3.0           4.0
# 959  American Double / Imperial IPA                4.5           4.5
# 961                 American Porter                4.0           4.5
# 968                English Pale Ale                3.5           4.0
# 971  American Double / Imperial IPA                5.0           4.5
# 972  American Double / Imperial IPA                4.5           4.5
# 975         American Pale Ale (APA)                4.0           4.0
# 976          Saison / Farmhouse Ale                4.0           4.0
# 980          Russian Imperial Stout                4.0           4.0
# 987                   Oatmeal Stout                4.0           4.0
# 989          Russian Imperial Stout                5.0           4.0
# 992         American Pale Ale (APA)                3.5           4.0
# 993         Belgian Strong Dark Ale                4.0           4.0
# 995          Saison / Farmhouse Ale                4.0           3.5
#
#      review_overall  review_palate     profile_name  review_taste  \
# 0               4.5            4.0         blaheath           4.5
# 1               4.5            4.0             GJ40           4.0
# 2               3.0            3.0         biegaman           3.5
# 6               4.5            4.0           Deuane           4.5
# 7               4.5            4.5           n0rc41           4.5
# 10              4.5            4.5         blaheath           4.5
# 11              4.5            4.0       Daniellobo           4.0
# 13              4.5            4.5            drtth           4.5
# 21              3.5            4.0       abuliarose           4.0
# 22              4.0            4.0         drcarver           4.0
# 23              5.0            4.5             ALeF           5.0
# 26              4.5            4.5           n0rc41           4.5
# 28              4.5            4.0        sisuspeed           4.0
# 30              3.5            3.0           tone77           3.0
# 33              4.5            4.5         cdizinno           4.5
# 40              3.5            3.5           armock           3.5
# 44              4.5            4.5        Cylinsier           5.0
# 52              4.5            4.5       Mistofminn           4.5
# 55              5.0            5.0  MrHurmateeowish           4.5
# 56              5.0            4.5     nickspagnolo           4.5
# 58              4.5            4.0       Mistofminn           4.0
# 60              4.5            4.0         meatyard           4.0
# 67              4.5            4.0        brewdoc75           5.0
# 69              4.5            4.0       beerthulhu           4.5
# 71              5.0            4.5        Marcrates           4.5
# 75              4.0            3.5       beerthulhu           3.5
# 77              3.5            3.5       beerthulhu           4.0
# 80              2.5            2.5        wertperch           2.5
# 81              5.0            4.0        MrDanno96           4.5
# 84              4.5            4.0    philipquarles           4.5
# ..              ...            ...              ...           ...
# 909             4.5            4.0             Finn           4.0
# 910             4.5            4.5      mikesgroove           4.5
# 914             4.5            4.5    womencantsail           4.0
# 915             5.0            4.5     beermanbrian           5.0
# 916             4.5            4.5      mikesgroove           4.5
# 918             4.5            3.0    taylorhamrick           3.5
# 919             4.5            4.0          therica           4.5
# 921             4.5            5.0        ChugsMugs           4.5
# 930             4.5            4.5     xpimptastikx           4.5
# 931             3.5            3.5       scoobybrew           3.5
# 933             4.5            4.0             GJ40           4.0
# 934             3.0            3.0       RedDiamond           3.5
# 936             2.0            2.0            Viggo           2.0
# 940             4.5            4.0       brewandbbq           4.0
# 942             4.5            4.0     Ezekiel81923           4.5
# 948             4.5            4.0          tempest           3.5
# 950             5.0            4.0     Ezekiel81923           4.5
# 959             4.5            4.0            gibby           4.5
# 961             4.5            4.0         bmanning           4.5
# 968             5.0            3.5           mwa423           4.5
# 971             5.0            4.5         jbhuxley           5.0
# 972             4.5            4.5        jackorain           4.5
# 975             4.5            4.0            Jayli           4.0
# 976             4.5            4.0  ClockworkOrange           4.0
# 980             4.5            4.0        kirok1999           4.0
# 987             4.5            4.5             GJ40           4.0
# 989             4.5            4.0             SamN           3.0
# 992             4.5            4.0      thespaceman           4.0
# 993             4.5            4.0  ClockworkOrange           4.0
# 995             5.0            4.0           Kraken           4.5
#
#                                                   text                time
# 0     Batch 8144\tPitch black in color with a 1/2 f... 2009-10-05 21:31:48
# 1     Sampled from a 12oz bottle in a standard pint... 2009-10-05 21:32:09
# 2     Haystack yellow with an energetic group of bu... 2009-10-05 21:32:13
# 6     An American amber with the addition of smoked... 2009-10-05 21:34:24
# 7     Ok, for starters great white I believe will b... 2009-10-05 21:34:29
# 10    Burnt amber in color with a 1/4" head. Aroma ... 2009-10-05 21:36:03
# 11    A very pleasing PA leaning strongly on the IP... 2009-10-05 21:37:48
# 13    Lightly chilled and poured into a Duvel glass... 2009-10-05 21:40:18
# 21    Poured into a snifter, revealing black opaque... 2009-10-05 21:47:36
# 22    A - a medium brown body with an off white hea... 2009-10-05 21:47:56
# 23    As a devoted drinker of American and English ... 2009-10-05 21:48:46
# 26    Poured a great dark color with great smell! t... 2009-10-05 21:51:33
# 28    The color of this beer fits the name well. Op... 2009-10-05 21:53:38
# 30    Poured from a brown 12oz. bottle. Has an ambe... 2009-10-05 22:01:09
# 33    Presentation: Poured into a tulip glass from ... 2009-10-05 22:02:19
# 40    A - Poured a hazy orange color with a white h... 2009-10-05 22:11:53
# 44    Poured from a 75 cl. \t\tPours a faintly hazy... 2009-10-05 22:13:30
# 52    Had this on tap at the Herkimer.\t\tServed in... 2009-10-05 22:27:57
# 55    16oz brown bottle, batch #3, purchased at Who... 2009-10-05 22:32:15
# 56    A: It is a copper/red colored beer whose foam... 2009-10-05 22:32:32
# 58    Had this on tap during happy hour at the Herk... 2009-10-05 22:33:38
# 60    Pours a nicely carbonated, clear amber with 2... 2009-10-05 22:36:30
# 67    Picked up a sixer of this when I was in WI.\t... 2009-10-05 22:49:03
# 69    A: In the light appeared a deep mahogany, whi... 2009-10-05 22:49:26
# 71    A - This is a beautiful looking beer. A very ... 2009-10-05 22:51:30
# 75    4.0% abv. \t\tA: Poured into a pint with a ro... 2009-10-05 22:55:10
# 77    A: Poured a crystal golen-orange with a thin,... 2009-10-05 22:57:38
# 80    I had one of these at a local curry house. Po... 2009-10-05 23:06:44
# 81    A: Pours an opaque, light golden color with a... 2009-10-05 23:06:59
# 84    375ml bottle. Pours a deep, fairly clear garn... 2009-10-05 23:10:14
# ..                                                 ...                 ...
# 909   This Fest beer is an incredibly clear, deep g... 2009-10-07 00:48:26
# 910   So I think this is supposed to be a big IPA, ... 2009-10-07 00:49:46
# 914   A: I poured this into my Cigar City snifter t... 2009-10-07 00:51:17
# 915   I've been wanting to try this one for years. ... 2009-10-07 00:51:41
# 916   Picked this one up as an extra in a BIF and j... 2009-10-07 00:52:18
# 918   Nice color, fairly clear, though a bit of yea... 2009-10-07 00:52:30
# 919   A grand porter against which to judge others.... 2009-10-07 00:53:39
# 921   A- Poured with a mega head that dominated the... 2009-10-07 00:54:14
# 930   Finally found a bottle of this on my Belgium ... 2009-10-07 01:00:04
# 931   This was poured into a pint glass.\t\tA - dee... 2009-10-07 01:00:04
# 933   Sampled from a 22oz bottle purchased at Whole... 2009-10-07 01:00:27
# 934   Iron Horse's website lists Rodeo at 4% ABV, w... 2009-10-07 01:01:35
# 936   650 ml bottle from the LCBO. These new labels... 2009-10-07 01:01:55
# 940   24oz bottle from the fridge. 13th release of ... 2009-10-07 01:06:35
# 942   22oz bomber via trade. Thank you kindly alley... 2009-10-07 01:07:33
# 948   From the bottle, it poured near black with a ... 2009-10-07 01:14:53
# 950   22oz bomber via trade thanks to Alleykatking.... 2009-10-07 01:16:02
# 959   Finally showed up in this area, picked up a b... 2009-10-07 01:21:05
# 961   Pours a viscous black with thin tan head.\tSm... 2009-10-07 01:23:05
# 968   A - Poured a hazy copper color with about a h... 2009-10-07 01:29:21
# 971   This is the last survivor of the 4 pack that ... 2009-10-07 01:29:47
# 972   Pours a golden copper color with a slight haz... 2009-10-07 01:29:57
# 975   consumed 10/2/09\tThis beer pours a murky dee... 2009-10-07 01:30:37
# 976   A capped and corked 750ml bottle split with p... 2009-10-07 01:30:43
# 980   Pours a deep black, legs on the glass and alm... 2009-10-07 01:39:02
# 987   Sampled from a 22oz bottle purchased at Pike ... 2009-10-07 01:50:50
# 989   Bomber purchased from Campus West Liquors and... 2009-10-07 01:54:05
# 992   Had on tap at Smokin' With Chris in Southingt... 2009-10-07 01:57:03
# 993   This bottle has been in the cellar for at lea... 2009-10-07 01:57:56
# 995   Reviewed 10/6/09\t\tPoured from a corked and ... 2009-10-07 01:58:45
#
# [353 rows x 13 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>Exercise</b>: Find the American beers
# </div>
#
# Select just the rows where the `beer_style` contains `'American'`.
#
# Hint: `Series` containing strings have a bunch of [useful methods](http://pandas.pydata.org/pandas-docs/stable/text.html#method-summary) under the `DataFrame.<column>.str` namespace. Typically they correspond to regular python string methods, but
#
# - They gracefully propogate missing values
# - They're a bit more liberal about accepting regular expressions
#
# We can't use `'American' in df['beer_style']`, since `in` is used to check membership in the series itself, not the strings. But `in` uses `__contains__`, so look for a string method like that.

# %%
df.beer_style.str.contains("American")

# %%
# Your solution
is_ipa = df.beer_style.str.contains("American")
df[is_ipa]

# %% [markdown]
# ## Groupby

# %% [markdown]
# Groupby is a fundamental operation to pandas and data analysis.
#
# The components of a groupby operation are to
#
# 1. Split a table into groups
# 2. Apply a function to each group
# 3. Combine the results
#
# In pandas the first step looks like
#
# ```python
# df.groupby( grouper )
# ```
#
# `grouper` can be many things
#
# - Series (or string indicating a column in `df`)
# - function (to be applied on the index)
# - dict : groups by *values*
# - `levels=[ names of levels in a MultiIndex ]`

# %%
gr = df.groupby('beer_style')
gr

# %% [markdown]
# Haven't really done anything yet. Just some book-keeping to figure out which **keys** go with which **rows**. Keys are the things we've grouped by (each `beer_style` in this case).
#
# The last two steps, apply and combine, are just:

# %%
gr.agg('mean')
# Out:
#                                           abv       beer_id     brewer_id  \
# beer_style
# Altbier                              5.850000  43260.500000    419.500000
# American Adjunct Lager               4.872727  12829.909091   2585.909091
# American Amber / Red Ale             6.195652  28366.777778   2531.111111
# American Amber / Red Lager           4.822857  22277.500000   5620.125000
# American Barleywine                 10.208333  32457.250000   3744.083333
# American Black Ale                   8.600000  48415.500000  10051.500000
# American Blonde Ale                  5.488889  22984.800000   2672.800000
# American Brown Ale                   6.021875  20128.812500   5674.687500
# American Double / Imperial IPA       9.163425  32345.219178   3857.753425
# American Double / Imperial Pilsner   9.166667  45911.333333   6257.333333
# American Double / Imperial Stout    10.148485  31672.911765   5088.500000
# American IPA                         6.788060  29821.764706   4084.926471
# American Malt Liquor                 7.900000  23066.000000    269.500000
# American Pale Ale (APA)              5.316061  24617.060606   4038.212121
# American Pale Lager                  4.850000   4343.750000    418.250000
# American Pale Wheat Ale              5.318667  28315.187500   2909.437500
# American Porter                      6.713333  26726.031250   3762.125000
# American Stout                       6.523571  13464.187500   2617.312500
# American Strong Ale                  9.353333  29298.687500   3944.437500
# American Wild Ale                    8.090000  39232.650000   5260.200000
# Baltic Porter                        8.983333  34600.666667   3279.333333
# Belgian Dark Ale                     6.742857  42758.857143   1159.857143
# Belgian IPA                          8.514286  33389.428571    691.428571
# Belgian Pale Ale                     6.496154  21630.461538   2430.615385
# Belgian Strong Dark Ale              8.890000  25889.062500   2787.375000
# Belgian Strong Pale Ale              8.510714  20637.071429   2470.142857
# Berliner Weissbier                   3.566667  41738.500000  11105.250000
# Bière de Garde                       6.460000  32784.800000   2593.900000
# Bock                                 6.566667   2167.000000    920.666667
# California Common / Steam Beer       5.300000  44143.000000  14154.000000
# ...                                       ...           ...           ...
# Keller Bier / Zwickel Bier           4.700000  36454.833333   6525.333333
# Kristalweizen                        5.400000    760.000000    252.000000
# Kölsch                               4.622222  37344.555556   5474.888889
# Lambic - Fruit                       6.000000  22166.500000   1131.500000
# Lambic - Unblended                  11.000000  37811.000000   5221.000000
# Light Lager                          4.200000  38640.600000   1499.200000
# Maibock / Helles Bock                7.000000  11953.333333    689.666667
# Milk / Sweet Stout                   6.615385  38650.230769   3316.307692
# Munich Dunkel Lager                  5.150000  27229.500000   1498.000000
# Munich Helles Lager                  4.998571  24064.142857   1186.571429
# Märzen / Oktoberfest                 5.905405  20803.609756   2284.219512
# Oatmeal Stout                        5.710000  24748.800000   2010.600000
# Old Ale                             11.800000  18237.909091   4983.454545
# Pumpkin Ale                          6.906667  28375.937500   4753.343750
# Quadrupel (Quad)                    10.771429  19554.714286   2179.285714
# Rauchbier                            5.400000  14625.000000   6372.000000
# Roggenbier                           5.500000  52028.000000    417.000000
# Russian Imperial Stout               9.978571  17745.214286   4011.142857
# Rye Beer                             8.250000  24151.000000   4684.250000
# Sahti                               11.000000  46302.000000   7730.000000
# Saison / Farmhouse Ale               7.566250  38020.840000   4805.160000
# Schwarzbier                          4.928571  20236.000000   3000.750000
# Scotch Ale / Wee Heavy               8.747000  22118.200000   3445.200000
# Scottish Ale                         5.250000   3671.000000   2664.000000
# Smoked Beer                          6.755714  41283.142857   4455.571429
# Tripel                               9.329412  16027.705882   2882.882353
# Vienna Lager                         4.985714  19497.750000   6180.750000
# Weizenbock                           8.350000  19540.500000    250.000000
# Wheatwine                           11.075000  36980.000000    629.600000
# Witbier                              6.175000  27346.600000   3583.700000
#
#                                     review_appearance  review_aroma  \
# beer_style
# Altbier                                      4.000000      3.750000
# American Adjunct Lager                       2.954545      2.613636
# American Amber / Red Ale                     3.740741      3.592593
# American Amber / Red Lager                   3.437500      3.312500
# American Barleywine                          3.958333      3.937500
# American Black Ale                           4.500000      4.250000
# American Blonde Ale                          3.200000      2.850000
# American Brown Ale                           3.812500      3.968750
# American Double / Imperial IPA               4.178082      4.164384
# American Double / Imperial Pilsner           4.000000      3.666667
# American Double / Imperial Stout             4.264706      4.147059
# American IPA                                 4.044118      4.022059
# American Malt Liquor                         3.250000      3.000000
# American Pale Ale (APA)                      3.666667      3.439394
# American Pale Lager                          3.500000      3.000000
# American Pale Wheat Ale                      3.593750      3.375000
# American Porter                              4.078125      3.984375
# American Stout                               3.968750      3.781250
# American Strong Ale                          3.843750      4.062500
# American Wild Ale                            4.075000      4.275000
# Baltic Porter                                4.500000      4.000000
# Belgian Dark Ale                             3.785714      3.857143
# Belgian IPA                                  3.928571      3.714286
# Belgian Pale Ale                             3.846154      3.730769
# Belgian Strong Dark Ale                      4.062500      3.843750
# Belgian Strong Pale Ale                      4.000000      4.035714
# Berliner Weissbier                           3.625000      4.250000
# Bière de Garde                               3.850000      3.900000
# Bock                                         3.666667      2.666667
# California Common / Steam Beer               3.750000      3.750000
# ...                                               ...           ...
# Keller Bier / Zwickel Bier                   3.583333      3.333333
# Kristalweizen                                5.000000      4.500000
# Kölsch                                       4.000000      3.611111
# Lambic - Fruit                               4.000000      4.125000
# Lambic - Unblended                           5.000000      4.500000
# Light Lager                                  2.700000      2.700000
# Maibock / Helles Bock                        4.166667      3.833333
# Milk / Sweet Stout                           3.923077      4.076923
# Munich Dunkel Lager                          3.500000      3.250000
# Munich Helles Lager                          3.642857      3.428571
# Märzen / Oktoberfest                         3.804878      3.597561
# Oatmeal Stout                                4.200000      3.850000
# Old Ale                                      4.000000      4.409091
# Pumpkin Ale                                  3.609375      3.843750
# Quadrupel (Quad)                             4.214286      4.071429
# Rauchbier                                    3.500000      3.500000
# Roggenbier                                   3.500000      4.500000
# Russian Imperial Stout                       4.303571      4.232143
# Rye Beer                                     4.125000      4.250000
# Sahti                                        4.000000      4.000000
# Saison / Farmhouse Ale                       3.820000      3.740000
# Schwarzbier                                  3.437500      3.375000
# Scotch Ale / Wee Heavy                       3.900000      4.000000
# Scottish Ale                                 3.750000      4.000000
# Smoked Beer                                  4.071429      3.928571
# Tripel                                       4.264706      4.088235
# Vienna Lager                                 3.500000      3.250000
# Weizenbock                                   4.000000      3.750000
# Wheatwine                                    3.800000      4.000000
# Witbier                                      3.750000      3.650000
#
#                                     review_overall  review_palate  \
# beer_style
# Altbier                                   4.000000       3.750000
# American Adjunct Lager                    3.272727       2.909091
# American Amber / Red Ale                  3.870370       3.555556
# American Amber / Red Lager                3.375000       3.187500
# American Barleywine                       3.729167       3.895833
# American Black Ale                        3.750000       4.000000
# American Blonde Ale                       2.900000       2.900000
# American Brown Ale                        3.937500       3.687500
# American Double / Imperial IPA            3.986301       4.095890
# American Double / Imperial Pilsner        3.333333       3.666667
# American Double / Imperial Stout          4.058824       4.161765
# American IPA                              4.066176       3.860294
# American Malt Liquor                      2.500000       2.750000
# American Pale Ale (APA)                   3.833333       3.621212
# American Pale Lager                       3.250000       3.000000
# American Pale Wheat Ale                   3.625000       3.375000
# American Porter                           4.062500       3.843750
# American Stout                            3.750000       3.593750
# American Strong Ale                       3.937500       3.781250
# American Wild Ale                         4.225000       4.350000
# Baltic Porter                             4.500000       4.166667
# Belgian Dark Ale                          3.785714       4.142857
# Belgian IPA                               4.142857       3.857143
# Belgian Pale Ale                          3.730769       3.692308
# Belgian Strong Dark Ale                   3.781250       3.875000
# Belgian Strong Pale Ale                   4.000000       4.035714
# Berliner Weissbier                        4.750000       4.250000
# Bière de Garde                            3.800000       3.800000
# Bock                                      3.666667       3.833333
# California Common / Steam Beer            3.750000       4.000000
# ...                                            ...            ...
# Keller Bier / Zwickel Bier                3.833333       3.833333
# Kristalweizen                             5.000000       5.000000
# Kölsch                                    4.166667       3.666667
# Lambic - Fruit                            4.125000       4.125000
# Lambic - Unblended                        4.500000       4.500000
# Light Lager                               2.900000       2.700000
# Maibock / Helles Bock                     4.166667       4.000000
# Milk / Sweet Stout                        3.846154       3.923077
# Munich Dunkel Lager                       4.000000       3.500000
# Munich Helles Lager                       4.000000       3.714286
# Märzen / Oktoberfest                      3.890244       3.768293
# Oatmeal Stout                             4.100000       4.050000
# Old Ale                                   4.181818       4.318182
# Pumpkin Ale                               3.531250       3.609375
# Quadrupel (Quad)                          4.000000       3.857143
# Rauchbier                                 4.000000       4.500000
# Roggenbier                                4.000000       4.000000
# Russian Imperial Stout                    4.160714       4.160714
# Rye Beer                                  3.875000       4.125000
# Sahti                                     4.000000       4.000000
# Saison / Farmhouse Ale                    4.060000       3.860000
# Schwarzbier                               3.625000       3.687500
# Scotch Ale / Wee Heavy                    3.700000       3.800000
# Scottish Ale                              4.000000       3.875000
# Smoked Beer                               4.000000       4.000000
# Tripel                                    3.970588       3.911765
# Vienna Lager                              3.375000       3.562500
# Weizenbock                                4.250000       4.250000
# Wheatwine                                 3.500000       4.000000
# Witbier                                   3.600000       3.550000
#
#                                     review_taste
# beer_style
# Altbier                                 4.000000
# American Adjunct Lager                  2.750000
# American Amber / Red Ale                3.777778
# American Amber / Red Lager              3.125000
# American Barleywine                     3.937500
# American Black Ale                      4.000000
# American Blonde Ale                     3.000000
# American Brown Ale                      3.906250
# American Double / Imperial IPA          4.136986
# American Double / Imperial Pilsner      3.500000
# American Double / Imperial Stout        4.205882
# American IPA                            3.985294
# American Malt Liquor                    2.500000
# American Pale Ale (APA)                 3.545455
# American Pale Lager                     3.375000
# American Pale Wheat Ale                 3.562500
# American Porter                         3.875000
# American Stout                          3.843750
# American Strong Ale                     4.125000
# American Wild Ale                       4.400000
# Baltic Porter                           3.833333
# Belgian Dark Ale                        3.928571
# Belgian IPA                             4.071429
# Belgian Pale Ale                        3.730769
# Belgian Strong Dark Ale                 3.843750
# Belgian Strong Pale Ale                 4.071429
# Berliner Weissbier                      4.500000
# Bière de Garde                          3.750000
# Bock                                    3.666667
# California Common / Steam Beer          4.250000
# ...                                          ...
# Keller Bier / Zwickel Bier              3.666667
# Kristalweizen                           5.000000
# Kölsch                                  4.000000
# Lambic - Fruit                          4.250000
# Lambic - Unblended                      4.500000
# Light Lager                             2.800000
# Maibock / Helles Bock                   4.166667
# Milk / Sweet Stout                      4.000000
# Munich Dunkel Lager                     3.250000
# Munich Helles Lager                     3.500000
# Märzen / Oktoberfest                    3.695122
# Oatmeal Stout                           3.950000
# Old Ale                                 4.454545
# Pumpkin Ale                             3.625000
# Quadrupel (Quad)                        4.214286
# Rauchbier                               3.500000
# Roggenbier                              4.500000
# Russian Imperial Stout                  4.232143
# Rye Beer                                4.125000
# Sahti                                   4.000000
# Saison / Farmhouse Ale                  3.840000
# Schwarzbier                             3.312500
# Scotch Ale / Wee Heavy                  4.000000
# Scottish Ale                            3.750000
# Smoked Beer                             3.928571
# Tripel                                  4.176471
# Vienna Lager                            3.312500
# Weizenbock                              4.250000
# Wheatwine                               3.700000
# Witbier                                 3.650000
#
# [93 rows x 8 columns]

# %%
df.groupby('beer_style').mean()

# %% [markdown]
# This says apply the `mean` function to each column. Non-numeric columns (nusiance columns) are excluded. We can also select a subset of columns to perform the aggregation on.

# %%
gr[review_cols].agg('mean')

# %% [markdown]
# `.` attribute lookup works as well.

# %%
gr.abv.agg('mean')

# %% [markdown]
# Certain operations are attached directly to the `GroupBy` object, letting you bypass the `.agg` part

# %%
gr.abv.mean()

# %% [markdown]
# Now we'll run the gamut on a bunch of grouper / apply combinations.
# Keep sight of the target though: split, apply, combine.
#
# - Grouper: Controls the output index
#     * single grouper -> `Index`
#     * array-like grouper -> `MultiIndex`
# - Subject (Groupee): Controls the output data values
#     * single column -> `Series` (or DataFrame if multiple aggregations)
#     * multiple columns -> `DataFrame`
# - Aggregation: Controls the output columns
#     * single aggfunc -> `Index` in the colums
#     * multiple aggfuncs -> `MultiIndex` in the columns (Or 1-D Index groupee is 1-d)

# %% [markdown]
# Multiple Aggregations on one column

# %%
gr['review_aroma'].agg(['mean', 'std', 'count']).head()
# Out:
#                                 mean       std  count
# beer_style
# Altbier                     3.750000  0.353553      2
# American Adjunct Lager      2.613636  0.596255     22
# American Amber / Red Ale    3.592593  0.636049     27
# American Amber / Red Lager  3.312500  0.842509      8
# American Barleywine         3.937500  0.449940     24

# %% [markdown]
# Single Aggregation on multiple columns

# %%
gr[review_cols].mean()

# %% [markdown]
# Multiple aggregations on multiple columns

# %%
gr[review_cols].agg(['mean', 'count', 'std'])

# %% [markdown]
# Hierarchical Indexes in the columns can be awkward to work with, so I'll usually
# move a level to the Index with `.stack`.

# %%
multi = gr[review_cols].agg(['mean', 'count', 'std']).stack(level=0)
multi.head(10)

# %% [markdown]
# You can group by **levels** of a MultiIndex.

# %%
multi.groupby(level='beer_style')['mean'].agg(['min', 'max'])

# %% [markdown]
# Group by **multiple** columns

# %%
df.groupby(['brewer_id', 'beer_style']).review_overall.mean()

# %%
df.groupby(['brewer_id', 'beer_style'])[review_cols].mean()
